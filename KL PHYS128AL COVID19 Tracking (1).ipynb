# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Day 1
# ### [RN] January 31st, 3:40 pm
#
# I read Part I and went to the first group meeting last friday. I will go through the lab manual and answer questions in Part II to start developing my code.

# %% [markdown]
# ## The Life Cycle of a Virus
# This section primarily serves as background and introduction.

# %%
### Question 1

# get reproduction rate from given
production = 10000    # copies 1 virus generates in given time interval
dt = 0.5     # time interval


# calculate propogation 
V_population = 1    # start with 1 virus
infection_rate = 0.1   # ten percent 
time_elapsed = 0    # c ount time 
C_infected = 0   # number of cells infected starts at zero

while C_infected < 10**12: 
        V_population = V_population * production    # each virus produces 10000 more for each generation 
        C_infected = V_population*infection_rate    # how many cells would be infected total for this many viruses
        time_elapsed = time_elapsed + dt 
        
print("It will take ", time_elapsed, " days to produce enough viruses to infect 1 trillion cells, given that one virus produces ", production, " over ", dt, "days")
# Out:
# It will take  2.0  days to produce enough viruses to infect 1 trillion cells, given that one virus produces  10000  over  0.5 days

# %%
### Question 2

transmission = 3 # each person transmits to 3 people
dt = 1 # over one week 

infected_pop = 1 # start with one infected person
time_elapsed = 0
total_time = 4*3 # assuming four weeks in each months, total time is three months 

while time_elapsed <= total_time:
    infected_pop = infected_pop*3 # every person in population spreads to three others
    time_elapsed = time_elapsed + dt # iterate by week 
    
print("After three months, if each person infects three others, there will have been ", infected_pop, " infections total.")
# Out:
# After three months, if each person infects three others, there will have been  1594323  infections total.

# %% [markdown]
# ## The SIR Model

# %% [markdown]
# ### Infected
# This section explores the number of people infected as a function of time, or I(t). It is important to note that k is the number of people each infected person infects per day. The units of per day are important on k.
#
# I can already see that this model is a brutal oversimplification of the actual model, but it is a good place to start. The [CDC breaks up the k value](https://www.cdc.gov/coronavirus/2019-ncov/hcp/planning-scenarios.html) (they call it R0) by age group and scenario, taking much more into account like if an individual is asymptomatic or not. I will use that data later to make a better mode. For now we will just look at the most basic model.
#
# The differential I am working with here is:
#
# I'(t) = I0 * k

# %%
### Question 3
plt.rcParams['figure.figsize'] = [13, 8]
e = (1+(1/(1000000)))**1000000

def Infections_t(k, t, I0):
    It = I0 * e**(k*t)
    return It
days = 7 
t_dat = np.linspace(0, days) # plot time over ten days 

I0 = 1 # start with one infected person 

# Plot linearly
fig1, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace':0.1})
for i in range(1, 5):
    I_dat = np.zeros(len(t_dat))
    I_lndat = np.zeros(len(t_dat))
    k = i
    for j in range(len(t_dat)):
        I_dat[j] = Infections_t(k, t_dat[j], I0)
        I_lndat[j] = math.log(Infections_t(k, t_dat[j], I0))
    axs[0].plot(t_dat, I_dat, label = "k="+str(k))
    slope = (1/days)*(I_lndat[len(I_lndat)-1]-I_lndat[0])
    axs[1].plot(t_dat, I_lndat, label = "k="+str(k))  
plt.xlabel("Days passed")
plt.ylabel("Infected People")
fig1.suptitle("Infected people per day, each infected person infects k people")
axs[0].set_title("Number of Infected Individuals per Day")
axs[1].set_title("Logarithmic Scale Infections per Day (k = slope)")
axs[0].legend()
axs[1].legend()

# %% [markdown]
# ### [RN] 4:10 pm
# It seems like it will be necessary to include logarithmic plots throughout this project. The linear scale plot shows very little due to the rapid exponential growth. Always having both plots will be complementary and gives more information.
#
# Additionally, as the notebook points out, this model is unrealistic. I only showed one week of infections, but this model does not account for people's recovery and people who have immunity for some reason or another, among other things. The CDC data I found will be much more useful for a real model, but I will come back to that later.

# %% [markdown]
# ### Susceptible

# %% [markdown]
# Only S(t) people are actually susceptible at a time in a population of N people. Thus S(0) = N -1, and S(t) = N - I(t). This is important because not every person that an individual comes into contact with will be susceptible.
#
# The differential for S'(t) is:
#
# S'(t) = - I'(t) = -k*I(t)
# S(t) = -I(t) = -I0exp(kt))
#
# also:
#
# I'(t) = k*S(t)*(1/N)*(I(t))
#
# so:
# ln(I(t)) = S0*(k/N)*S(t)
#
# I(t) = S0exp((k/N)*S(t))
#
# Given equation t4, I(t) + S(t) = N at all times because:
#
# I0*N + S0*N*exp(-kt) = N ( I0 + S0*exp(-kt))
#
# The demoninator of equations 4 is ( I0 + S0*exp(-kt)), so for all t, I(t) + S(t) = N
#
# We can see in the code below that I(t) + S(t) is always N

# %%
### Question 6

# I need to plot the solution involging S and I 

N = 10000 # set population size 
I0 = 1
S0 = N-I0

# write functions for equation 4
def I_t(I0, S0, k, t, N): 
    top = I0*N
    bottom = I0 + S0*e**(-k*t)
    return top/bottom

def S_t(I0, S0, k, t, N): 
    top = S0*N*e**(-k*t)
    bottom = I0 + S0*e**(-k*t)
    return top/bottom

# Plot 
fig2, axs2 = plt.subplots(2, sharex=True, gridspec_kw={'hspace':0.1})
S_dat, I_dat = np.zeros(len(t_dat)), np.zeros(len(t_dat))
S_lndat, I_lndat = np.zeros(len(t_dat)), np.zeros(len(t_dat))
k = 3
non_N_count = 0 # count any instances where I(t)+S(t) is not N
for j in range(len(t_dat)):     # get data over 7 days for I(t) and S(t)
    S_dat[j] = S_t(I0, S0, k, t_dat[j], N)
    S_lndat[j] = math.log(S_t(I0, S0, k, t_dat[j], N))
    I_dat[j] = I_t(I0, S0, k, t_dat[j], N)
    I_lndat[j] = math.log(I_t(I0, S0, k, t_dat[j], N))
    I_dat[j] = I_t(I0, S0, k, t_dat[j], N)
    if round(S_t(I0, S0, k, t_dat[j], N) + I_t(I0, S0, k, t_dat[j], N)) != N: # check that total is always N
            print("S(t) + I(t) not equal to N!")
            non_N_count = non_N_count + 1
            
# give linear and lograritmically scaled plots 
axs2[0].plot(t_dat, S_dat, label = "Susceptible population")
axs2[0].plot(t_dat, I_dat, label = "Infected population")
slope = (1/days)*(S_lndat[len(S_lndat)-1]-S_lndat[0])
axs2[1].plot(t_dat, S_lndat, label = "Susceptible population")  
axs2[1].plot(t_dat, I_lndat, label = "Infected population")  

plt.xlabel("Days passed")
plt.ylabel("Infected People")
fig2.suptitle("Number of Susceptible People, Population N=" + str(N))
axs2[0].set_title("Number of Susceptible Individuals per Day, k =3")
axs2[1].set_title("Logarithmic Scale Susceptible Population per Day")
axs2[0].legend()
axs2[1].legend()


print("There were ", non_N_count, "instances where S(t) and I(t) did not add up to N. ")
# Out:
# There were  0 instances where S(t) and I(t) did not add up to N.

# %% [markdown]
# ### Removed
#
# Now we need to use R(t) to keep track of removed population. Removal rate us 1/T, with T being the number of days an individual is infectious on average.

# %%
## write a basic SIR function. I will solve by iterating over time steps. 

def SIR_noR0(I0, N, k, T, dt, duration):
    g = float(1/T)
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 

# total should always be N. This is good to check, so ill make it a function 
def CheckTotal(S, I, R, N): 
    nonN = 0
    for i in range(len(S)):
        total = S[i] + I[i] + R[i]
        if round(total, 0) != N:
            nonN = nonN+1
    if nonN == 0:
        return True # SIR all add up to N at any given time
    else:
        return False # something went wrong. total is not N. 

def LnData(dat):   # ill be making log graphs often, so ill write a function to convert data 
    lndat = np.zeros(len(dat))
    for i in range(len(dat)):
        lndat[i] = math.log(dat[i])
    return lndat

# define parameters 
N = 1000 # population size 
T = 7 # number of days each person is infectios for
k = 3 # number of people each infections person infects each day 
dt = 0.1 # timestep i want to go by
duration = 7 # number of days i want to model

S, I, R = SIR_noR0(1, N, k, T, dt, duration)
print("S, I, R add up to N at all times: ", CheckTotal(S, I, R, N))

t_dat = np.linspace(0, 7, len(S))
fig3, axs3 = plt.subplots(2, sharex=True, gridspec_kw={'hspace':0.1})

#Plot with linear axes
axs3[0].plot(t_dat, S, label = "Susceptible population")
axs3[0].plot(t_dat, I, label = "Infected population")
axs3[0].plot(t_dat, R, label = "Removed population")
plt.ylabel("Infected People")
# plot with logarithmic axes 
axs3[1].plot(t_dat, LnData(S), label = "Susceptible population")
axs3[1].plot(t_dat, LnData(I), label = "Infected population")
axs3[1].plot(t_dat, LnData(R), label = "Removed population")


plt.xlabel("Days passed")

fig3.suptitle("SIR model, Population N=" + str(N) + "T = "+str(T) + " day infections period, k = "+str(k)+ "people infected per individual")
axs3[0].set_title("Linear Scale")
axs3[1].set_title("Logarithmic Scale")
axs3[0].legend()
axs3[1].legend()
# Out:
# S, I, R add up to N at all times:  True

# %% [markdown]
# I can see that this model makes much more sense than initial ones. SIR follows conservation laws, as seen by the fact that S, I, and R add up to N at all times (with some deviation corrected by rounding to nearest integer). This model has tons of room for improvement by breaking up demographics with population and CDC published data. I can also use this model to fit real data and study COVID-19 spread in different ways; such as by county, age group, or occupation.
#
# Issues I still see are the fact that people can get the virus twice after a certain amount of time, introduction of vaccinations, and death rate.
#
# Next I will modify my function to accomodate the R0 value.

# %%
### work in R0 as R0 = k/g

plt.rcParams['figure.figsize'] = [13, 20]
def SIR(I0, N, k, R0, dt, duration):
    g = k/R0
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 


t_dat = np.linspace(0, 7, len(S))
plots = 6
fig4, axs4 = plt.subplots(plots, sharex=True, gridspec_kw={'hspace':0.1})
N =100
I0 = 10
R0 = [0.1, 0.5, 1, 1.5, 5, 10]
for i in range(plots):
    S, I, R = SIR(I0, N, k, R0[i], dt, duration)
    axs4[i].plot(t_dat, S, label = "Susceptible population")
    axs4[i].plot(t_dat, I, label = "Infected population")
    axs4[i].plot(t_dat, R, label = "Removed population")
    axs4[i].set_title("R0="+str(R0[i]))
    axs4[i].legend()


plt.xlabel("Days passed")
fig4.suptitle("SIR model: Population N=" + str(N) + ", I0 = "+str(I0) + " initial people infected, each person infects k = "+str(k)+ " others")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: overflow encountered in double_scalars
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: overflow encountered in double_scalars
#   from ipykernel import kernelapp as app
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in double_scalars
# Text(0.5, 0.98, 'SIR model: Population N=100, I0 = 10 initial people infected, each person infects k = 3 others')

# %% [markdown]
# ### [RN] 5:54 pm
#
# I can see that if R0 is less than one, the virus goes away and it is not really an epidemic. The infected population never rises above the number of people initially infected, everyone just gets better.
#
# The model breaks for very small R0 values, as seen in the first plot where R0 =0.1. The covid-19 pandemic is defintently not behaving like that, so unfortunately this model will work fine and this is not an issue. One observation here is that the lines for S and R do not intersect.
#
# If R0=1, then the infected population overtime does go down over time, but just barely. The slope of I(t) is negative everywehre, but the maximum number of people are infected for this to still be true. Now the lines for S and R do interesect.
#
# If R0>1, then the disease spreads and infected population reaches a maximum around where R and S interesct. The epidemic spreads to more of the population when R0>>1 than it does when R0 is just a bit over one.

# %% [markdown]
# # [KL]
# The goal is to extend this model until herd immunity is reached. Herd immunity should drive down the S(t) value, as vaccinated individuals are no longer susceptible. To govern this, the general equation should include some function V(t), which I will use to define the number of vaccinated individuals at some time t.
#
# Herd immunity can be defined as the point where a population has enough members who can be classified as either recovered or vaccinated, and the infectious individuals lack the carriers to continue the spread. Because of this, the number of individuals who need to either have been moved to the R subgroup or the V subgroup must total some ratio that causes the R_0 to be less than one.
#
# Since R_0 = k/g, there are a few possibilities on how this could occur.

# %% [markdown]
# # [KL]
#
# We know the rate of change for S(t), dS/dt, can be represented by a decreasing function, where the factor 'k' governs the rate of decrease in possible susceptible individuals. Likewise, there is the factor 'g' that governs the change in removed individuals over time, dR/dt, as the number of recovered people + the number of deaths can only increase over time.
#
# An important aspect to look at is how either of these parameters individually affects the behavior of the I(t) graph; in other words, both of these factors can be isolated and assessed to analyze how they change the rates of infection both by magnitude and by speed.
#
# In order to model this, I graphed 4 different combinations of the k and g factors, thereby affecting the R_0. From Rebeccas findings, we should expect a higher g value (higher recovery per infection rate) to cause the virus to eventually fade (i.e. the limit of dI/dt should approach zero).
#
# Because a large g value corresponds to a smaller T value, the parameters in the code above for the base SIR model are adjusted accordingly.
#
# I define large as = 10 and small as = 1. Trends should be easily observable through these numbers. For the case of g, since it is an inverse of T, this will also be adjusted accordingly and noted in each graph title.
# The corresponding graphs are not valid functions of the SIR model; they are only to show the effects of variables and to highlight the overall goal.

# %%
## write a basic SIR function. I will solve by iterating over time steps. 

def SIR_noR0(I0, N, k, T, dt, duration):
    g = float(1/T)
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 

# total should always be N. This is good to check, so ill make it a function 
def CheckTotal(S, I, R, N): 
    nonN = 0
    for i in range(len(S)):
        total = S[i] + I[i] + R[i]
        if round(total, 0) != N:
            nonN = nonN+1
    if nonN == 0:
        return True # SIR all add up to N at any given time
    else:
        return False # something went wrong. total is not N. 

def LnData(dat):   # ill be making log graphs often, so ill write a function to convert data 
    lndat = np.zeros(len(dat))
    for i in range(len(dat)):
        lndat[i] = math.log(dat[i])
    return lndat

#this code is written by Rebecca Nishide, I am only changing individual parameters
#parameters below are changed to show the individual effects of variables k and g 

# define parameters 
N = 1000 # population size 
T = 25 # number of days each person is infectios for
k = 1 # number of people each infections person infects each day 
dt = 0.1 # timestep i want to go by
duration = 100 # number of days i want to model

S, I, R = SIR_noR0(1, N, k, T, dt, duration)
#print("S, I, R add up to N at all times: ", CheckTotal(S, I, R, N))

t_dat = np.linspace(0, 7, len(S))
fig3, axs3 = plt.subplots(2, sharex=True, gridspec_kw={'hspace':0.1})

#plot with linear axes
axs3[0].plot(t_dat, I, label = "Infected population")
plt.ylabel("Infected People")
plt.xlabel("Days passed")

fig3.suptitle("SIR model, Population N=" + str(N) + "T = "+str(T) + " day infections period, k = "+str(k)+ "people infected per individual")
axs3[0].set_title("Small k, small g, large T values: Linear Scale")
axs3[1].plot(t_dat, LnData(I), label = "Infected population")
axs3[1].set_title("Small k, small g, large T values: Logarithmic Scale")

axs3[0].legend()
axs3[1].legend()

# %% [markdown]
# # [KL] PLEASE HELP ME DELETE THE SECOND GRAPH

# %%
## write a basic SIR function. I will solve by iterating over time steps. 

def SIR_noR0(I0, N, k, T, dt, duration):
    g = float(1/T)
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 

# total should always be N. This is good to check, so ill make it a function 
def CheckTotal(S, I, R, N): 
    nonN = 0
    for i in range(len(S)):
        total = S[i] + I[i] + R[i]
        if round(total, 0) != N:
            nonN = nonN+1
    if nonN == 0:
        return True # SIR all add up to N at any given time
    else:
        return False # something went wrong. total is not N. 

def LnData(dat):   # ill be making log graphs often, so ill write a function to convert data 
    lndat = np.zeros(len(dat))
    for i in range(len(dat)):
        lndat[i] = math.log(dat[i])
    return lndat

#this code is written by Rebecca Nishide, I am only changing individual parameters
#parameters below are changed to show the individual effects of variables k and g 

# define parameters 
N = 1000 # population size 
T = 1 # number of days each person is infectios for
k = 25 # number of people each infections person infects each day 
dt = 0.1 # timestep i want to go by
duration = 100 # number of days i want to model

S, I, R = SIR_noR0(1, N, k, T, dt, duration)
#print("S, I, R add up to N at all times: ", CheckTotal(S, I, R, N))

t_dat = np.linspace(0, 7, len(S))
fig3, axs3 = plt.subplots(2, sharex=True, gridspec_kw={'hspace':0.1})

#plot with linear axes
axs3[0].plot(t_dat, I, label = "Infected population")
plt.ylabel("Infected People")
plt.xlabel("Days passed")

fig3.suptitle("SIR model, Population N=" + str(N) + "T = "+str(T) + " day infections period, k = "+str(k)+ "people infected per individual")
axs3[0].set_title("Large k, large g, small T values: Linear Scale")
axs3[1].plot(t_dat, LnData(I), label = "Infected population")
axs3[1].set_title("Large k, large g, small T values: Logarithmic Scale")

axs3[0].legend()
axs3[1].legend()

# %%
## write a basic SIR function. I will solve by iterating over time steps. 

def SIR_noR0(I0, N, k, T, dt, duration):
    g = float(1/T)
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 

# total should always be N. This is good to check, so ill make it a function 
def CheckTotal(S, I, R, N): 
    nonN = 0
    for i in range(len(S)):
        total = S[i] + I[i] + R[i]
        if round(total, 0) != N:
            nonN = nonN+1
    if nonN == 0:
        return True # SIR all add up to N at any given time
    else:
        return False # something went wrong. total is not N. 

def LnData(dat):   # ill be making log graphs often, so ill write a function to convert data 
    lndat = np.zeros(len(dat))
    for i in range(len(dat)):
        lndat[i] = math.log(dat[i])
    return lndat

#this code is written by Rebecca Nishide, I am only changing individual parameters
#parameters below are changed to show the individual effects of variables k and g 

# define parameters 
N = 1000 # population size 
T = 1.1 # number of days each person is infectios for
k = 1 # number of people each infections person infects each day 
dt = 0.1 # timestep i want to go by
duration = 100 # number of days i want to model

S, I, R = SIR_noR0(1, N, k, T, dt, duration)
#print("S, I, R add up to N at all times: ", CheckTotal(S, I, R, N))

t_dat = np.linspace(0, 7, len(S))
fig3, axs3 = plt.subplots(2, sharex=True, gridspec_kw={'hspace':0.1})

#plot with linear axes
axs3[0].plot(t_dat, I, label = "Infected population")
plt.ylabel("Infected People")
plt.xlabel("Days passed")

fig3.suptitle("SIR model, Population N=" + str(N) + "T = "+str(T) + " day infections period, k = "+str(k)+ "people infected per individual")
axs3[0].set_title("Small k, large g, small T values: Linear Scale")
axs3[1].plot(t_dat, LnData(I), label = "Infected population")
axs3[1].set_title("Small k, large g, small T values: Logarithmic Scale")

axs3[0].legend()
axs3[1].legend()

# %%
## write a basic SIR function. I will solve by iterating over time steps. 

def SIR_noR0(I0, N, k, T, dt, duration):
    g = float(1/T)
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 

# total should always be N. This is good to check, so ill make it a function 
def CheckTotal(S, I, R, N): 
    nonN = 0
    for i in range(len(S)):
        total = S[i] + I[i] + R[i]
        if round(total, 0) != N:
            nonN = nonN+1
    if nonN == 0:
        return True # SIR all add up to N at any given time
    else:
        return False # something went wrong. total is not N. 

def LnData(dat):   # ill be making log graphs often, so ill write a function to convert data 
    lndat = np.zeros(len(dat))
    for i in range(len(dat)):
        lndat[i] = math.log(dat[i])
    return lndat

#this code is written by Rebecca Nishide, I am only changing individual parameters
#parameters below are changed to show the individual effects of variables k and g 

# define parameters 
N = 1000 # population size 
T = 10 # number of days each person is infectios for
k = 10 # number of people each infections person infects each day 
dt = 0.1 # timestep i want to go by
duration = 100 # number of days i want to model

S, I, R = SIR_noR0(1, N, k, T, dt, duration)
#print("S, I, R add up to N at all times: ", CheckTotal(S, I, R, N))

t_dat = np.linspace(0, 7, len(S))
fig3, axs3 = plt.subplots(2, sharex=True, gridspec_kw={'hspace':0.1})

#plot with linear axes
axs3[0].plot(t_dat, I, label = "Infected population")
plt.ylabel("Infected People")
plt.xlabel("Days passed")

fig3.suptitle("SIR model, Population N=" + str(N) + "T = "+str(T) + " day infections period, k = "+str(k)+ "people infected per individual")
axs3[0].set_title("Large k, small g, large T values: Linear Scale")
axs3[1].plot(t_dat, LnData(I), label = "Infected population")
axs3[1].set_title("Large k, small g, large T values: Logarithmic Scale")

axs3[0].legend()
axs3[1].legend()

# %% [markdown]
# # [KL]
# Clearly, the most ideal case occurs when k and g are both small (and T is large). k controls the height of the peak, whereas g controls how condensed this peak is. Higher k values lead to higher peaks, and higher g values lead to more condensed (sharp) peaks. The ideal scenario is a low and dull peak, which corresponds with projected COVID cases from social distancing and lockdown models from other studies. This can be seen with any search for the CNC's predictions.
#
# Since the R_0 is calculated using these two values, the R_0 provides useful information for predicting when herd immunity can occur. Earlier, the results of multiple R_0 values were tested, and these R_0 values can subsequently be applied to calculate the number of individuals that would need to be vaccinated before herd immunity is achieved.
#
# Herd immunity threshold (HIT) is given by a formula that can be applied to any R_0. In order for this to be realistic, it depends on the accuracy of the calculated R_0. One important factor to note: Although HIT can be applied to this model, in reality, HIT is typically used for a scenario where random vaccination occurs in a community. This lacks to account for the natural immunity that occurs when individuals are moved to the R subgroup from the I subgroup, as the original model assumes that individuals who are removed have 0% chance of being susceptible again, and are no longer possible candidates for the S subgroup.
#
# Another important factor is that vaccination is time-dependent event; it does not fully occur at any particular point and so the HIT is only used to find the percentage of individuals who need to be in the R subgroup for the population to have herd immunity. This brings up another point, as populations can obtain herd immunity from  a combination of R subgroups: A fraction from recovered or deceased individuals and a fraction from vaccinated individuals.

# %%
#using the same values from earlier graphs for N, I, R

N =100
I0 = 10
R0 = [0.1, 0.5, 1, 1.5, 5, 10]

#HIT: number of individuals that must be vaccinated (in this case, removed) for herd immunity 
#The equation that governs HIT: 

H = 1 - (1/R0)

#how do i make this print a list of all the values of H you would get from the above values of R0? sos
#anyways, i would personally make this list print out
#list of H values represents the proportion of N that needs to be in R for the growth of virus to halt and subside
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-290c4c8a8cfe> in <module>
#       8 #The equation that governs HIT:
#       9
# ---> 10 H = 1 - (1/R0)
#      11
#      12 print(H)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'list'

# %% [markdown]
# # [KL]!! REBECCA SOS READ THE LAST LINE
# Let's say the R0 values of 2 and 5 are used, arbitrarily chosen.
# If R0 = 2, then the HIT equation yields 1/2, or 50%.
# If R0 = 5, then the HIT equation yields 4/5, or 80%. This indicates 80% of the population in N must be moved to the R subgroup for the I(t) graph to stop moving exponentially upwards, whether this be done through a vaccine or a removal.
# For this to happen, we need to study how the I(t) chart moves without vaccination. Referring back to Rebecca's code:
#
# PLEASE CHOOSE BETTER NUMBERS SO THE GRAPHS ARE PRETTIER OR ZOOM IN

# %%
# work in R0 as R0 = k/g

plt.rcParams['figure.figsize'] = [13, 20]
def SIR(I0, N, k, R0, dt, duration):
    g = k/R0
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 


#setting N to 1000 so results are more clear

t_dat = np.linspace(0, 100, len(S))
plots = 2
fig4, axs4 = plt.subplots(plots, sharex=True, gridspec_kw={'hspace':0.1})
N =1000
I0 = 1
R0 = [2, 5]
for i in range(plots):
    S, I, R = SIR(I0, N, k, R0[i], dt, duration)
    axs4[i].plot(t_dat, S, label = "Susceptible population")
    axs4[i].plot(t_dat, I, label = "Infected population")
    axs4[i].plot(t_dat, R, label = "Removed population")
    axs4[i].set_title("R0="+str(R0[i]))
    axs4[i].legend()


plt.xlabel("Days passed")
fig4.suptitle("SIR model: Population N=" + str(N) + ", I0 = "+str(I0) + " initial people infected, each person infects k = "+str(k)+ " others")
# Out:
# Text(0.5, 0.98, 'SIR model: Population N=1000, I0 = 1 initial people infected, each person infects k = 10 others')

# %% [markdown]
# # [KL] OK HERE WHAT I'M TRYING TO DO IS MAKE A PLOT OF HOW IT WOULD LOOK WITH
# R0 = 2 AND R STARTED AT 500 PEOPLE (HALF OF THE ORIGINAL N, WHICH I USED 1000 FOR)
# and R0 = 5 IF R STARTED AT 800 PEOPLE, 4/5 OF THE ORIGINAL N
# BASICALLY NOT THE SIMULATION BUT JUST A VISUAL FOR WHAT WOULD HAPPEN TO THE MOVEMENT OF THE GRAPH WHEN THE HIT LEVEL IS REACHED. THE EXPONENTIAL BEHAVIOR IS SUPPOSED TO DIE OFF.
#
#
# The graph's behavior is extreme. Based on the N used, N = 1000, it is easy to calculate the HIT for both cases. In the R0 = 2 case, only 50% of the population needs to be vaccinated. Therefore, in the case where 500 people are in the R subgroup:

# %%
# work in R0 as R0 = k/g

plt.rcParams['figure.figsize'] = [13, 20]
def SIR(I0, N, k, R0, dt, duration):
    g = k/R0
    j = int(duration/dt)
    time_elapsed = 0 # go for duration, iterating by dt
    I, S, R = np.zeros(j), np.zeros(j), np.zeros(j) # i will iterate and fill these in with values 
    R[0] = g*I0 # set initial values as given. 
    I[0] = I0
    S[0] = N-1
    for i in range(1, j): # increment SIR by dt. eg X(t+dt) = X(t) + dX. Log totals in the arrays. 
        dR = g*I[i-1]*dt # get dX values from equation 6
        dI = ((k/N)*S[i-1]*I[i-1]-g*I[i-1])*dt
        dS = -(k/N) * S[i-1]*I[i-1]*dt
        I[i] = I[i-1]+dI  # add increment to last value X(t) to get X(t+dt)
        R[i] = R[i-1]+dR
        S[i] = S[i-1]+dS
    return S, I, R   # return S, I, and R arrays indexed by time. 


#setting N to 1000 so results are more clear

t_dat = np.linspace(0, 100, len(S))
plots = 2
fig4, axs4 = plt.subplots(plots, sharex=True, gridspec_kw={'hspace':0.1})
N = 1000
I0 = 1
R0 = [2, 5]
for i in range(plots):
    S, I, R = SIR(I0, N, k, R0[i], dt, duration)
    axs4[i].plot(t_dat, S, label = "Susceptible population")
    axs4[i].plot(t_dat, I, label = "Infected population")
    axs4[i].plot(t_dat, R, label = "Removed population")
    axs4[i].set_title("R0="+str(R0[i]))
    axs4[i].legend()



plt.xlabel("Days passed")
fig4.suptitle("SIR model: Population N=" + str(N) + ", I0 = "+str(I0) + " initial people infected, each person infects k = "+str(k)+ " others")
# Out:
# Text(0.5, 0.98, 'SIR model: Population N=1000, I0 = 1 initial people infected, each person infects k = 10 others')

# %% [markdown]
# # [KL]
# The number for H in both cases, 200 and 500 respectively, can be incorporated into the basic SIR equation. But first, the equation that governs the rate at which the vaccine is distributed and taken must be found. The rate at which it is distributed can be governed by a slow exponential rate, and the rate at which it is taken should be similar whilst subtracting yet another equation that governs the likelihood that an antivaxxer will deny it. Additionally, antivaxxer groups have notably been on the rise, especially for COVID, and the probability that a single vaccine will be offered to someone belonging to the antivaxxer group can be modeled by deriving a few equations.
#
#
# 1. equation to govern the rate at which vaccine is distributed "offered" to those in the S subgroup.
#         1a. potentially go deeper by incorporating which members of the S subgroup are offered the vaccine first
#             (aka those that are more likely to be moved into the I category and subsequently, the R category)
#
# 2. equation to govern the prevalence of antivaxxers, and subtract this equation from equation 1.
#         2a. similar to 1a, if we break down the S group into "more likely to move to I group" and "normal
#             likelihood to move to I group", the "more likely" subcategory can be targeted with antivaxxer
#             prevalence
#         2b. another possibility to look further into behavioral statistics: the growth of antivaxxers. most
#             likely will not pursue this method because antivaxxer growth is a whole seperate SIR model in
#             itself and this would be too complex to include into this model.
#
#
# Essentially, the most important two factors to focus on in our project is a) the equation that governs how quickly people can get access to the vaccine (as each vaccinated individual causes an increasing effect on new infections and decreases rate), and b) the equation that governs the likelihood that someone may refuse to get a vaccine, and these antivaxxers will represent a setback (or slowing down) the rate at which herd immunity is achieved.
#
#
# Two more things to focus on, but in my opinion are not as crucial currently:
#
# 3. the effectiveness of the vaccine, so allow the vaccine to be governed by an equation that can be adjusted based on the probability that it will work (some percentage in the 90s, most likely)
#
# 4. with the three equations outlined above, the time it takes until herd immunity is reached (so R = H) can be calculated based on:
#
# ( rate of vaccine distribution minus rate of antivaxxer refusal ) * vaccine effectiveness
#
# I have no idea how to code so I did most of these calculations by hand to figure out how they work.
